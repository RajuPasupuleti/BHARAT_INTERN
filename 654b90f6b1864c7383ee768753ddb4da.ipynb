# %% [markdown]
# > house_price_prediction
# > July 31, 2023
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><p>[25]: <strong>import pandas as pd</strong></p>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p><strong>import numpy as np</strong><br />
# <strong>import seaborn as sns</strong><br />
# <strong>import matplotlib.pyplot as plt</strong></p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>[26]:</th>
# <th colspan="7"><p>[26]: HouseDF = pd.read_csv('housing_price.csv')</p>
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>HouseDF.head()</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td rowspan="18">[26]:</td>
# <td colspan="2"><blockquote>
# <p>Avg. Area Income</p>
# </blockquote></td>
# <td colspan="2">Avg. Area House Age</td>
# <td colspan="3">Avg. Area Number of Rooms</td>
# <td rowspan="18"><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>\</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="even">
# <td>0</td>
# <td colspan="2"><blockquote>
# <p>79545.45857</p>
# </blockquote></td>
# <td colspan="2"><blockquote>
# <p>5.682861</p>
# </blockquote></td>
# <td colspan="2">7.009188</td>
# </tr>
# <tr class="odd">
# <td>1</td>
# <td colspan="2"><blockquote>
# <p>79248.64245</p>
# </blockquote></td>
# <td colspan="2"><blockquote>
# <p>6.002900</p>
# </blockquote></td>
# <td colspan="2">6.730821</td>
# </tr>
# <tr class="even">
# <td>2</td>
# <td colspan="2"><blockquote>
# <p>61287.06718</p>
# </blockquote></td>
# <td colspan="2"><blockquote>
# <p>5.865890</p>
# </blockquote></td>
# <td colspan="2">8.512727</td>
# </tr>
# <tr class="odd">
# <td>3</td>
# <td colspan="2"><blockquote>
# <p>63345.24005</p>
# </blockquote></td>
# <td colspan="2"><blockquote>
# <p>7.188236</p>
# </blockquote></td>
# <td colspan="2">5.586729</td>
# </tr>
# <tr class="even">
# <td>4</td>
# <td colspan="2"><blockquote>
# <p>59982.19723</p>
# </blockquote></td>
# <td colspan="2"><blockquote>
# <p>5.040555</p>
# </blockquote></td>
# <td colspan="2">7.839388</td>
# </tr>
# <tr class="odd">
# <td colspan="3"><blockquote>
# <p>Avg. Area Number of Bedrooms</p>
# </blockquote></td>
# <td colspan="2"><blockquote>
# <p>Area Population</p>
# </blockquote></td>
# <td>Price</td>
# <td><blockquote>
# <p>\</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>0</td>
# <td colspan="2">4.09</td>
# <td colspan="2">23086.80050</td>
# <td colspan="2"><blockquote>
# <p>1.059034e+06</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>1</td>
# <td colspan="2">3.09</td>
# <td colspan="2">40173.07217</td>
# <td colspan="2"><blockquote>
# <p>1.505891e+06</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>2</td>
# <td colspan="2">5.13</td>
# <td colspan="2">36882.15940</td>
# <td colspan="2"><blockquote>
# <p>1.058988e+06</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>3</td>
# <td colspan="2">3.26</td>
# <td colspan="2">34310.24283</td>
# <td colspan="2"><blockquote>
# <p>1.260617e+06</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>4</td>
# <td colspan="2">4.23</td>
# <td colspan="2">26354.10947</td>
# <td colspan="2"><blockquote>
# <p>6.309435e+05</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td colspan="7">Address</td>
# </tr>
# <tr class="even">
# <td>0</td>
# <td colspan="6"><blockquote>
# <p>208 Michael Ferry Apt. 674\nLaurabury, NE 3701…</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>1</td>
# <td colspan="6"><blockquote>
# <p>188 Johnson Views Suite 079\nLake Kathleen, CA…</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>2</td>
# <td colspan="6"><blockquote>
# <p>9127 Elizabeth Stravenue\nDanieltown, WI 06482…</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>3</td>
# <td colspan="6">USS Barnett\nFPO AP 44820</td>
# </tr>
# <tr class="even">
# <td>4</td>
# <td colspan="6">USNS Raymond\nFPO AE 09386</td>
# </tr>
# </tbody>
# </table>
#
# > \[6\]: HouseDF.info()
#
# <table>
# <colgroup>
# <col style="width: 25%" />
# <col style="width: 25%" />
# <col style="width: 25%" />
# <col style="width: 25%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th colspan="3">&lt;class 'pandas.core.frame.DataFrame'&gt; RangeIndex:
# 5000 entries, 0 to 4999 Data columns (total 7 columns):</th>
# <th rowspan="5"><blockquote>
# <p>Dtype<br />
# -----<br />
# float64<br />
# float64</p>
# </blockquote></th>
# </tr>
# <tr class="odd">
# <th><blockquote>
# <p>#</p>
# </blockquote></th>
# <th><blockquote>
# <p>Column</p>
# </blockquote></th>
# <th>Non-Null Count</th>
# </tr>
# <tr class="header">
# <th>---</th>
# <th><blockquote>
# <p>------</p>
# </blockquote></th>
# <th>--------------</th>
# </tr>
# <tr class="odd">
# <th><blockquote>
# <p>0</p>
# </blockquote></th>
# <th><blockquote>
# <p>Avg. Area Income</p>
# </blockquote></th>
# <th>5000 non-null</th>
# </tr>
# <tr class="header">
# <th><blockquote>
# <p>1</p>
# </blockquote></th>
# <th><blockquote>
# <p>Avg. Area House Age</p>
# </blockquote></th>
# <th>5000 non-null</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# 1
#
# <table>
# <colgroup>
# <col style="width: 25%" />
# <col style="width: 25%" />
# <col style="width: 25%" />
# <col style="width: 25%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>2</th>
# <th><blockquote>
# <p>Avg. Area Number of Rooms</p>
# </blockquote></th>
# <th>5000 non-null</th>
# <th><blockquote>
# <p>float64</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>3</td>
# <td>Avg. Area Number of Bedrooms</td>
# <td>5000 non-null</td>
# <td><blockquote>
# <p>float64</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>4</td>
# <td><blockquote>
# <p>Area Population</p>
# </blockquote></td>
# <td>5000 non-null</td>
# <td><blockquote>
# <p>float64</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td>5</td>
# <td><blockquote>
# <p>Price</p>
# </blockquote></td>
# <td>5000 non-null</td>
# <td><blockquote>
# <p>float64</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td>6</td>
# <td><blockquote>
# <p>Address</p>
# </blockquote></td>
# <td rowspan="3">5000 non-null</td>
# <td rowspan="3"><blockquote>
# <p>object</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td colspan="2"><blockquote>
# <p>dtypes: float64(6), object(1)</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td colspan="2"><blockquote>
# <p>memory usage: 273.6+ KB</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# \[7\]: HouseDF.describe()
#
# <table>
# <colgroup>
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# <col style="width: 11%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th rowspan="18">[7]:</th>
# <th rowspan="2">count</th>
# <th>Avg. Area Income</th>
# <th colspan="3">Avg. Area House Age</th>
# <th colspan="2">Avg. Area Number of Rooms</th>
# <th rowspan="18"><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>\</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></th>
# </tr>
# <tr class="odd">
# <th colspan="2">5000.000000</th>
# <th colspan="3"><blockquote>
# <p>5000.000000</p>
# </blockquote></th>
# <th>5000.000000</th>
# </tr>
# <tr class="header">
# <th><blockquote>
# <p>mean</p>
# </blockquote></th>
# <th colspan="3"><blockquote>
# <p>68583.108984</p>
# </blockquote></th>
# <th colspan="2"><blockquote>
# <p>5.977222</p>
# </blockquote></th>
# <th>6.987792</th>
# </tr>
# <tr class="odd">
# <th><blockquote>
# <p>std</p>
# </blockquote></th>
# <th colspan="3"><blockquote>
# <p>10657.991214</p>
# </blockquote></th>
# <th colspan="2"><blockquote>
# <p>0.991456</p>
# </blockquote></th>
# <th>1.005833</th>
# </tr>
# <tr class="header">
# <th><blockquote>
# <p>min</p>
# </blockquote></th>
# <th colspan="3"><blockquote>
# <p>17796.631190</p>
# </blockquote></th>
# <th colspan="2"><blockquote>
# <p>2.644304</p>
# </blockquote></th>
# <th>3.236194</th>
# </tr>
# <tr class="odd">
# <th><blockquote>
# <p>25%</p>
# </blockquote></th>
# <th colspan="3"><blockquote>
# <p>61480.562390</p>
# </blockquote></th>
# <th colspan="2"><blockquote>
# <p>5.322283</p>
# </blockquote></th>
# <th>6.299250</th>
# </tr>
# <tr class="header">
# <th><blockquote>
# <p>50%</p>
# </blockquote></th>
# <th colspan="3"><blockquote>
# <p>68804.286405</p>
# </blockquote></th>
# <th colspan="2"><blockquote>
# <p>5.970429</p>
# </blockquote></th>
# <th>7.002902</th>
# </tr>
# <tr class="odd">
# <th><blockquote>
# <p>75%</p>
# </blockquote></th>
# <th colspan="3"><blockquote>
# <p>75783.338665</p>
# </blockquote></th>
# <th colspan="2"><blockquote>
# <p>6.650808</p>
# </blockquote></th>
# <th>7.665871</th>
# </tr>
# <tr class="header">
# <th><blockquote>
# <p>max</p>
# </blockquote></th>
# <th colspan="3"><blockquote>
# <p>107701.748400</p>
# </blockquote></th>
# <th colspan="2"><blockquote>
# <p>9.519088</p>
# </blockquote></th>
# <th>10.759588</th>
# </tr>
# <tr class="odd">
# <th rowspan="2">count</th>
# <th colspan="3"><blockquote>
# <p>Avg. Area Number of Bedrooms</p>
# </blockquote></th>
# <th colspan="2">Area Population</th>
# <th>Price</th>
# </tr>
# <tr class="header">
# <th colspan="3">5000.000000</th>
# <th colspan="2">5000.000000</th>
# <th><blockquote>
# <p>5.000000e+03</p>
# </blockquote></th>
# </tr>
# <tr class="odd">
# <th><blockquote>
# <p>mean</p>
# </blockquote></th>
# <th colspan="3">3.981330</th>
# <th colspan="2">36163.516039</th>
# <th><blockquote>
# <p>1.232073e+06</p>
# </blockquote></th>
# </tr>
# <tr class="header">
# <th><blockquote>
# <p>std</p>
# </blockquote></th>
# <th colspan="3">1.234137</th>
# <th colspan="2">9925.650114</th>
# <th><blockquote>
# <p>3.531176e+05</p>
# </blockquote></th>
# </tr>
# <tr class="odd">
# <th><blockquote>
# <p>min</p>
# </blockquote></th>
# <th colspan="3">2.000000</th>
# <th colspan="2">172.610686</th>
# <th><blockquote>
# <p>1.593866e+04</p>
# </blockquote></th>
# </tr>
# <tr class="header">
# <th><blockquote>
# <p>25%</p>
# </blockquote></th>
# <th colspan="3">3.140000</th>
# <th colspan="2">29403.928700</th>
# <th><blockquote>
# <p>9.975771e+05</p>
# </blockquote></th>
# </tr>
# <tr class="odd">
# <th><blockquote>
# <p>50%</p>
# </blockquote></th>
# <th colspan="3">4.050000</th>
# <th colspan="2">36199.406690</th>
# <th><blockquote>
# <p>1.232669e+06</p>
# </blockquote></th>
# </tr>
# <tr class="header">
# <th><blockquote>
# <p>75%</p>
# </blockquote></th>
# <th colspan="3">4.490000</th>
# <th colspan="2">42861.290770</th>
# <th><blockquote>
# <p>1.471210e+06</p>
# </blockquote></th>
# </tr>
# <tr class="odd">
# <th><blockquote>
# <p>max</p>
# </blockquote></th>
# <th colspan="3">6.500000</th>
# <th colspan="2">69621.713380</th>
# <th><blockquote>
# <p>2.469066e+06</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# \[8\]: HouseDF.columns
#
# \[8\]: Index(\['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area
# Number of Rooms', 'Avg. Area Number of Bedrooms', 'Area Population',
# 'Price', 'Address'\],
# dtype='object')
#
# \[9\]: sns.pairplot(HouseDF)
#
# | \[9\]: \<seaborn.axisgrid.PairGrid at 0x26c7239dff0\> |
# |-------------------------------------------------------|
#
# 2
#
# > <img
# > src="attachment:vertopal_654b90f6b1864c7383ee768753ddb4da/media/image1.png"
# > style="width:5.85in;height:5.85in" />
#
# \[36\]: sns.histplot(HouseDF\['Price'\])
#
# \[36\]: \<Axes: xlabel='Price', ylabel='Count'\>
#
# 3
#
# > <img
# > src="attachment:vertopal_654b90f6b1864c7383ee768753ddb4da/media/image2.png"
# > style="width:5.71111in;height:4.31944in" />
#
# \[11\]: X = HouseDF\[\['Avg. Area Income', 'Avg. Area House Age', 'Avg.
# Area Number of␣ ↪Rooms', 'Avg. Area Number of Bedrooms', 'Area
# Population'\]\]
#
# > y = HouseDF\['Price'\]
#
# | \[12\]: **from sklearn.model_selection import** train_test_split |
# |------------------------------------------------------------------|
#
# | \[13\]: X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4,␣ ↪random_state=101) |
# |------------------------------------------------------------------------|
# | \[27\]: **from sklearn.linear_model import** LinearRegression                                        |
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>lm = LinearRegression()</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th><blockquote>
# <p>lm.fit(X_train,y_train)</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# \[27\]: LinearRegression()
# \[42\]: print(lm.intercept\_)
# -2640159.7968132403
#
# 4
#
# <table>
# <colgroup>
# <col style="width: 33%" />
# <col style="width: 33%" />
# <col style="width: 33%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th colspan="3">[15]: coeff_DF =
# pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient']) coeff_DF</th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd">
# <td>[15]:</td>
# <td colspan="2"><table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>Coefficient</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table></td>
# </tr>
# <tr class="even">
# <td colspan="2"><blockquote>
# <p>Avg. Area Income</p>
# </blockquote></td>
# <td><blockquote>
# <p>21.528276</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td colspan="2"><blockquote>
# <p>Avg. Area House Age</p>
# </blockquote></td>
# <td><blockquote>
# <p>164883.282027</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td colspan="2"><blockquote>
# <p>Avg. Area Number of Rooms</p>
# </blockquote></td>
# <td><blockquote>
# <p>122368.678023</p>
# </blockquote></td>
# </tr>
# <tr class="odd">
# <td colspan="2"><blockquote>
# <p>Avg. Area Number of Bedrooms</p>
# </blockquote></td>
# <td><blockquote>
# <p>2233.801864</p>
# </blockquote></td>
# </tr>
# <tr class="even">
# <td colspan="2"><blockquote>
# <p>Area Population</p>
# </blockquote></td>
# <td><blockquote>
# <p>15.150420</p>
# </blockquote></td>
# </tr>
# </tbody>
# </table>
#
# \[16\]: predictions = lm.predict(X_test)
#
# \[54\]: plt.scatter(y_test,predictions)
#
# | \[54\]: \<matplotlib.collections.PathCollection at 0x26c7a2fbc10\> |
# |--------------------------------------------------------------------|
#
# > <img
# > src="attachment:vertopal_654b90f6b1864c7383ee768753ddb4da/media/image3.png"
# > style="width:5.46944in;height:4.45972in" />
#
# \[28\]: sns.histplot((y_test,predictions),bins=60);
#
# 5
#
# > <img
# > src="attachment:vertopal_654b90f6b1864c7383ee768753ddb4da/media/image4.png"
# > style="width:5.71111in;height:4.30972in" />
#
# \[19\]: **from sklearn import** metrics
#
# <table>
# <colgroup>
# <col style="width: 100%" />
# </colgroup>
# <thead>
# <tr class="header">
# <th>[20]: print('MAE:', metrics.mean_absolute_error(y_test,
# predictions))<br />
# print('MSE:', metrics.mean_squared_error(y_test, predictions))<br />
# print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test,
# predictions)))</th>
# </tr>
# </thead>
# <tbody>
# </tbody>
# </table>
#
# > MAE: 82288.22250721784
# > MSE: 10460958905.775047
# > RMSE: 102278.82921589907
#
# \[22\]:
#
# > \[ \]:
# >
# > \[ \]:
#
# 6
